# %% [markdown]
# # Report for exchanges data. This is to help users evaluate the various exchanges that they can use to buy/sell crypto currencies

# %%
import pandas as pd
import numpy as np
from requests import api 
from pycoingecko import CoinGeckoAPI

# %% [markdown]
# ### Define the dataframe

# %%
df_exchanges_data = pd.DataFrame(columns=['Rank', 'Logo', 'ID', 'Name', 'URL', 'trade_volume_24h_btc'], index=None)
df_exchanges_data.columns
# Out:
# Index(['Rank', 'Logo', 'ID', 'Name', 'URL', 'trade_volume_24h_btc'], dtype='object')

# %%
# The Python library pycoingecko deesnt have the method to get the exchanges data, so calling the GET request to the API instead
 
enpoint_url = f"https://api.coingecko.com/api/v3/exchanges"
exc_data_json = api.get(enpoint_url).json()
exc_data_json[0]
# Out:
# {'id': 'binance',
#  'name': 'Binance',
#  'year_established': 2017,
#  'country': 'Cayman Islands',
#  'description': '',
#  'url': 'https://www.binance.com/',
#  'image': 'https://assets.coingecko.com/markets/images/52/small/binance.jpg?1519353250',
#  'has_trading_incentive': False,
#  'trust_score': 10,
#  'trust_score_rank': 1,
#  'trade_volume_24h_btc': 374457.8101317302,
#  'trade_volume_24h_btc_normalized': 374457.8101317302}

# %%
for a in exc_data_json:

    name = a['name']
    year = a['year_established']
    country = a['country']
    

    exc_name = f'{name} - (est. {year}), {country}'
    # print(exc_name)

    # Markdown for Logo
    image_txt = a['name']
    image_url = a['image']
    logo  = f'![{image_txt}]({image_url})'

    # Markdown for link to website
    link = a['url']
    link_txt = 'Link'
    exc_link = f'[{ link_txt }]({ link })'

    trade_vol = round(a['trade_volume_24h_btc_normalized'], 2)

    df_exchanges_data = df_exchanges_data.append(pd.Series([
        a['trust_score_rank'],
        logo,
        a['id'],
        exc_name,
        exc_link,
        trade_vol
    ], index= df_exchanges_data.columns), ignore_index= True)

# %%
df_exchanges_data
# Out:
#    Rank                                               Logo               ID  \
# 0     1  ![Binance](https://assets.coingecko.com/market...          binance
# 1     2  ![Coinbase Exchange](https://assets.coingecko....             gdax
# 2     3  ![Bitfinex](https://assets.coingecko.com/marke...         bitfinex
# 3     4  ![FTX](https://assets.coingecko.com/markets/im...         ftx_spot
# 4     5  ![Kraken](https://assets.coingecko.com/markets...           kraken
# 5     6  ![Binance US](https://assets.coingecko.com/mar...       binance_us
# 6     7  ![Crypto.com Exchange](https://assets.coingeck...       crypto_com
# 7     8  ![Gemini](https://assets.coingecko.com/markets...           gemini
# 8     9  ![OKEx](https://assets.coingecko.com/markets/i...             okex
# 9    10  ![Huobi Global](https://assets.coingecko.com/m...            huobi
# 10   11  ![BKEX](https://assets.coingecko.com/markets/i...             bkex
# 11   12  ![P2PB2B](https://assets.coingecko.com/markets...           p2pb2b
# 12   13  ![BitMart](https://assets.coingecko.com/market...          bitmart
# 13   14  ![KuCoin](https://assets.coingecko.com/markets...           kucoin
# 14   15  ![WhiteBIT](https://assets.coingecko.com/marke...         whitebit
# 15   16  ![Gate.io](https://assets.coingecko.com/market...             gate
# 16   17  ![Bitstamp](https://assets.coingecko.com/marke...         bitstamp
# 17   18  ![Hotbit](https://assets.coingecko.com/markets...           hotbit
# 18   19  ![BtcTurk PRO](https://assets.coingecko.com/ma...          btcturk
# 19   20  ![MEXC Global](https://assets.coingecko.com/ma...              mxc
# 20   21  ![Bithumb Global](https://assets.coingecko.com...   bithumb_global
# 21   22  ![Poloniex](https://assets.coingecko.com/marke...         poloniex
# 22   23  ![Dex-Trade](https://assets.coingecko.com/mark...         dextrade
# 23   24  ![Bittrex](https://assets.coingecko.com/market...          bittrex
# 24   25  ![AscendEX (BitMax)](https://assets.coingecko....           bitmax
# 25   26  ![CEX.IO](https://assets.coingecko.com/markets...              cex
# 26   27  ![Bitso](https://assets.coingecko.com/markets/...            bitso
# 27   28  ![Bitcoin.com Exchange](https://assets.coingec...      bitcoin_com
# 28   29  ![ZB](https://assets.coingecko.com/markets/ima...               zb
# 29   30  ![Bitrue](https://assets.coingecko.com/markets...           bitrue
# ..  ...                                                ...              ...
# 70   71  ![Stormgain](https://assets.coingecko.com/mark...        stormgain
# 71   72  ![Korbit](https://assets.coingecko.com/markets...           korbit
# 72   73  ![eToroX](https://assets.coingecko.com/markets...           etorox
# 73   74  ![BTCMarkets](https://assets.coingecko.com/mar...       btcmarkets
# 74   75  ![Tokpie](https://assets.coingecko.com/markets...           tokpie
# 75   76  ![Zaif](https://assets.coingecko.com/markets/i...             zaif
# 76   77  ![Mercado Bitcoin](https://assets.coingecko.co...  mercado_bitcoin
# 77   78  ![Narkasa](https://assets.coingecko.com/market...          narkasa
# 78   79  ![Bamboo Relay](https://assets.coingecko.com/m...     bamboo_relay
# 79   80  ![TheRockTrading](https://assets.coingecko.com...   therocktrading
# 80   81  ![HitBTC](https://assets.coingecko.com/markets...           hitbtc
# 81   82  ![PancakeSwap (v2)](https://assets.coingecko.c...      pancakeswap
# 82   83  ![BW.com](https://assets.coingecko.com/markets...               bw
# 83   84  ![Uniswap (v2)](https://assets.coingecko.com/m...       uniswap_v2
# 84   85  ![Flybit](https://assets.coingecko.com/markets...           flybit
# 85   86  ![BTC-Alpha](https://assets.coingecko.com/mark...        btc_alpha
# 86   87  ![Changelly PRO](https://assets.coingecko.com/...        changelly
# 87   88  ![Phemex](https://assets.coingecko.com/markets...           phemex
# 88   89  ![ExMarkets](https://assets.coingecko.com/mark...        exmarkets
# 89   90  ![Sushiswap](https://assets.coingecko.com/mark...        sushiswap
# 90   91  ![GokuMarket](https://assets.coingecko.com/mar...             goku
# 91   92  ![Decoin](https://assets.coingecko.com/markets...           decoin
# 92   93  ![CoinFLEX](https://assets.coingecko.com/marke...         coinflex
# 93   94  ![Quickswap](https://assets.coingecko.com/mark...        quickswap
# 94   95  ![Liquid](https://assets.coingecko.com/markets...           quoine
# 95   96  ![CoinEx](https://assets.coingecko.com/markets...           coinex
# 96   97  ![EXMO](https://assets.coingecko.com/markets/i...             exmo
# 97   98  ![AlterDice](https://assets.coingecko.com/mark...        alterdice
# 98   99  ![GoPax](https://assets.coingecko.com/markets/...            gopax
# 99  100  ![KickEX](https://assets.coingecko.com/markets...           kickex
#
#                                                  Name  \
# 0               Binance - (est. 2017), Cayman Islands
# 1      Coinbase Exchange - (est. 2012), United States
# 2      Bitfinex - (est. 2014), British Virgin Islands
# 3              FTX - (est. 2019), Antigua and Barbuda
# 4                 Kraken - (est. 2011), United States
# 5             Binance US - (est. 2019), United States
# 6   Crypto.com Exchange - (est. 2019), Cayman Islands
# 7                 Gemini - (est. 2014), United States
# 8                          OKEx - (est. 2013), Belize
# 9              Huobi Global - (est. 2013), Seychelles
# 10         BKEX - (est. 2018), British Virgin Islands
# 11                      P2PB2B - (est. 2018), Estonia
# 12              BitMart - (est. 2017), Cayman Islands
# 13                   KuCoin - (est. 2014), Seychelles
# 14                    WhiteBIT - (est. 2018), Estonia
# 15                   Gate.io - (est. None), Hong Kong
# 16             Bitstamp - (est. 2013), United Kingdom
# 17                      Hotbit - (est. None), Estonia
# 18                  BtcTurk PRO - (est. 2013), Turkey
# 19                    MEXC Global - (est. 2018), None
# 20           Bithumb Global - (est. 2019), Seychelles
# 21                 Poloniex - (est. 2014), Seychelles
# 22            Dex-Trade - (est. 2019), United Kingdom
# 23               Bittrex - (est. 2014), United States
# 24         AscendEX (BitMax) - (est. 2018), Singapore
# 25               CEX.IO - (est. 2013), United Kingdom
# 26                        Bitso - (est. 2014), Mexico
# 27        Bitcoin.com Exchange - (est. 2019), Bahamas
# 28                            ZB - (est. 2017), China
# 29                    Bitrue - (est. 2018), Singapore
# ..                                                ...
# 70                      Stormgain - (est. None), None
# 71                  Korbit - (est. 2013), South Korea
# 72                    eToroX - (est. 2019), Gibraltar
# 73                BTCMarkets - (est. None), Australia
# 74                    Tokpie - (est. 2018), Hong Kong
# 75                          Zaif - (est. 2015), Japan
# 76              Mercado Bitcoin - (est. 2016), Brazil
# 77                      Narkasa - (est. 2020), Turkey
# 78              Bamboo Relay - (est. 2017), Australia
# 79                TheRockTrading - (est. 2011), Italy
# 80                         HitBTC - (est. 2013), None
# 81               PancakeSwap (v2) - (est. 2020), None
# 82                         BW.com - (est. 2017), None
# 83                   Uniswap (v2) - (est. 2018), None
# 84                  Flybit - (est. 2018), South Korea
# 85                      BTC-Alpha - (est. 2016), None
# 86            Changelly PRO - (est. 2020), Seychelles
# 87                    Phemex - (est. 2019), Singapore
# 88    ExMarkets - (est. 2018), British Virgin Islands
# 89                      Sushiswap - (est. 2020), None
# 90                GokuMarket - (est. 2019), Hong Kong
# 91                      Decoin - (est. 2017), Estonia
# 92                 CoinFLEX - (est. 2019), Seychelles
# 93                      Quickswap - (est. 2020), None
# 94                        Liquid - (est. 2014), Japan
# 95               CoinEx - (est. 2017), United Kingdom
# 96                 EXMO - (est. 2013), United Kingdom
# 97                 AlterDice - (est. 2018), Singapore
# 98                   GoPax - (est. 2016), South Korea
# 99                      KickEX - (est. 2020), Estonia
#
#                                                   URL  trade_volume_24h_btc
# 0                    [Link](https://www.binance.com/)             374457.81
# 1                    [Link](https://www.coinbase.com)              46918.22
# 2                    [Link](https://www.bitfinex.com)              43028.35
